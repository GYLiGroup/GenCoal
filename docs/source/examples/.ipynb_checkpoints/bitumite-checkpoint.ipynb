# %% [markdown]
# # bitumite
# Bitumite - Structural Model Construction with 80-95% Carbon content [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/VlachosGroup/LigninGraphs/blob/master/docs/source/examples/13_poplar_optimal_nonbranching.ipynb)

# %% [markdown]
# ### Install the package from pip (skip this step if the package is already installed)

# %%
# ! pip install clipirmol

# %% [markdown]
# ### Import package

# %%
# set absolute path of coal file directory (optional if installed via pip)
import sys, os
import json

# add customized coal package to sys.path for call modules in coal
sys.path.insert(0, '/home/liuhaodong/CoalModel')

print(sys.path)
print(os.getcwd())

# import python file from coal file directory
import coal.utils as ut
import coal.CoalGenerator as gen
import coal.ClipIRMol as clipirmol
# Out:
# ['/home/liuhaodong/CoalModel', '/home/liuhaodong/CoalModel/docs/source/examples', '/home/liuhaodong/.conda/envs/clipirmol/lib/python38.zip', '/home/liuhaodong/.conda/envs/clipirmol/lib/python3.8', '/home/liuhaodong/.conda/envs/clipirmol/lib/python3.8/lib-dynload', '', '/home/liuhaodong/.conda/envs/clipirmol/lib/python3.8/site-packages']
# /home/liuhaodong/CoalModel/docs/source/examples

# %% [markdown]
# ### ad to daf in elemental proportion

# %%
C_ad = 78.85  # 碳
N_ad = 1.44   # 氮
H_ad = 6.05  # 氢
S_ad = 0.26  # 硫
M = 2.51   # 水分
A = 1.66   # 灰分

C_daf, N_daf, H_daf, S_daf, O_daf = ut.ad2daf(C_ad, N_ad, H_ad, S_ad, M, A)
print(f"C_daf, N_daf, H_daf, S_daf, O_daf = {C_daf, N_daf, H_daf, S_daf, O_daf}")
# Out:
# O_ad= 9.230000000000004
# C_daf, N_daf, H_daf, S_daf, O_daf = (82.28112282166336, 1.5026609621204217, 6.313263070019827, 0.27131378482729834, 9.631639361369096)

# %%
# C_daf = 81.84
# N_daf = 1.49
# H_daf = 6.28
# S_daf = 0.27
# O_daf = 9.58
# M = 2.51   # 水分
# A = 1.66   # 灰分

# ut.daf2ad(C_daf, N_daf, H_daf, S_daf, O_daf, M, A)

# %%
# # 使用您提供的数据
# C_daf = 83.96
# N_daf = 3.81
# H_daf = 3.31
# S_daf = 0.39
# O_daf = 8.99
# M = 2.51  # 水分
# A = 1.66  # 灰分
				
# # 调用函数
# C_ad, N_ad, H_ad, S_ad, O_ad = ut.daf2ad(C_daf, N_daf, H_daf, S_daf, O_daf, M, A)
# print("ad基准下百分比:", C_ad, N_ad, H_ad, S_ad, O_ad)
# print("CNHSOMA和:", C_ad+N_ad+H_ad+S_ad+O_ad+M+A)

# %%
# C_ad = 80.92
# N_ad = 3.49   # 氮
# H_ad = 3.03  # 氢
# S_ad = 0.38  # 硫
# C_daf = 83.86
# O_daf = 8.99

# # C_ad = 74.37
# # N_ad = 1.21   # 氮
# # H_ad = 5.687  # 氢
# # S_ad = 0.342  # 硫
# # C_daf = 82.44
# # O_daf = 9.53
# ut.calculate_MA(C_ad, N_ad, H_ad, S_ad, C_daf, O_daf)

# %% [markdown]
# ### Import elemental proportion

# %%
# daf 	C	H	N	S	O
# 主2	89.76	4.74	1.45	1.78	2.27
# 主3	88.51	5.03	1.54	1.09	3.83
# 肥2	88.48	5.20	1.57	0.45	4.30
# 肥3	87.22	5.03	1.51	2.08	4.16
# 瘦2	90.34	4.45	1.55	1.00	2.66
# 瘦4	91.59	4.41	1.62	0.43	1.95
# FS
ele_ratio = {
        "C": 89.76,
        "H": 4.74,
        "N": 1.45,
        "S": 1.78,
        "O": 2.27
    }

# %% [markdown]
# ### Import CSV table of <sup>13</sup>C NMR

# %%
NMR_file_path = "bitumite/核磁300.csv"
C90, C180 = ut.calculate_C90_C180(NMR_file_path)
print("ppm>90 =", C90, ",ppm>180 =", C180)
# Out:
# ppm>90 = 0.872 ,ppm>180 = 0.044

# %% [markdown]
# ### Import CSV table of IR

# %%
# 输入红外文件
IR_file_path = 'bitumite/红外300.csv'

# 获取分子数据
retrieved_molecules = clipirmol.retrieve_small_molecules(IR_file_path)

# 打印红外光谱检索出来的小分子
# smiles_and_scores = clipirmol.convert_data_to_smiles_scores(retrieved_molecules)
# clipirmol.display_molecules(smiles_and_scores)

# %%
# 从retrieved_molecules获取SMILES字符串
selected_smiles = [mol['smiles'] for mol in retrieved_molecules]
extended_smiles_list = []

# 使用connect_rings_C4函数扩展这些SMILES字符串
for smiles in selected_smiles:
    extended_smiles = clipirmol.connect_rings_C4(smiles)
    extended_smiles = clipirmol.connect_rings_C4(extended_smiles)  # 再次扩展
    extended_smiles_list.append(extended_smiles)

# 更新updated_predicted_smiles_and_scores
updated_predicted_smiles_and_scores = [[(mol['smiles'], mol['score']) for mol in retrieved_molecules]]
for i, (smiles, score) in enumerate(updated_predicted_smiles_and_scores[0]):
    extended_smiles = extended_smiles_list[i]
    updated_predicted_smiles_and_scores[0][i] = (extended_smiles, score)

# clipirmol.display_molecules(updated_predicted_smiles_and_scores[0])

# 过滤SMILES
new_smiles_and_scores = clipirmol.filter_smiles_and_scores(updated_predicted_smiles_and_scores)
new_smiles_and_scores = [new_smiles_and_scores]

# 显示过滤后的图像
clipirmol.display_molecules(new_smiles_and_scores[0])

# %% [markdown]
# ### input molecule scale

# %%
data["C_atom"] = [300]

# %% [markdown]
# ### import bitumite.json as input

# %%
coal_smiles_list = [i[0] for i in new_smiles_and_scores[0]]

# 指定 JSON 文件名
filename = 'bitumite.json'

# 读取现有的 JSON 数据
with open(filename, 'r') as file:
    data = json.load(file)

# 更新 coal_smiles_list 的值
data['coal_smiles_list'] = coal_smiles_list
data['ele_ratio'] = ele_ratio
data['C90'] = C90
data['C180'] = C180
data['type'] = "bitumite"

# 将更新后的数据写回 JSON 文件
with open(filename, 'w') as file:
    json.dump(data, file, indent=4)

print("Update input information successfully!")
# Out:
# Update input information successfully!

# %%
## 读文件
data = ut.read_json('bitumite.json')

generator = gen.CoalGenerator(data)
current_smiles = generator.run()
# Out:
# Model has 0 O atom in carbonyl
# Model has 0 O atom in hydroxyl
# Target bitumite coal model with molecular formula C180H113O4N3S1
# Target attribute: {'C_N_ar': 160, 'C_al': 23, 'O_S': 5, 'H': 113}
# All combinations that meet the target C_N_ar: [{0: 0, 14: 9, 15: 0, 16: 1, 18: 1}, {0: 0, 14: 8, 15: 2, 16: 0, 18: 1}, {0: 0, 14: 8, 15: 0, 16: 3, 18: 0}, {0: 0, 14: 7, 15: 2, 16: 2, 18: 0}, {0: 0, 14: 6, 15: 4, 16: 1, 18: 0}, {0: 0, 14: 5, 15: 6, 16: 0, 18: 0}, {0: 0, 14: 5, 15: 0, 16: 0, 18: 5}, {0: 0, 14: 4, 15: 0, 16: 2, 18: 4}, {0: 0, 14: 3, 15: 2, 16: 1, 18: 4}, {0: 0, 14: 3, 15: 0, 16: 4, 18: 3}, {0: 0, 14: 2, 15: 4, 16: 0, 18: 4}, {0: 0, 14: 2, 15: 2, 16: 3, 18: 3}, {0: 0, 14: 2, 15: 0, 16: 6, 18: 2}, {0: 0, 14: 1, 15: 4, 16: 2, 18: 3}, {0: 0, 14: 1, 15: 2, 16: 5, 18: 2}, {0: 0, 14: 1, 15: 0, 16: 8, 18: 1}, {0: 0, 14: 0, 15: 6, 16: 1, 18: 3}, {0: 0, 14: 0, 15: 4, 16: 4, 18: 2}, {0: 0, 14: 0, 15: 2, 16: 7, 18: 1}, {0: 0, 14: 0, 15: 0, 16: 10, 18: 0}, {0: 0, 14: 0, 15: 0, 16: 1, 18: 8}]
# Evaluating combination 1/21
# Evaluating combination 2/21
# Evaluating combination 3/21
# Evaluating combination 4/21
# Evaluating combination 5/21
# Evaluating combination 6/21
# Evaluating combination 7/21
# Evaluating combination 8/21
# Evaluating combination 9/21
# Evaluating combination 10/21
# Evaluating combination 11/21
# Evaluating combination 12/21
# Evaluating combination 13/21
# Evaluating combination 14/21
# Evaluating combination 15/21
# Evaluating combination 16/21
# Evaluating combination 17/21
# Evaluating combination 18/21
# Evaluating combination 19/21
# Evaluating combination 20/21
# Evaluating combination 21/21
# The selection with the minimum total H is: {15: {1: 4, 2: 0}, 14: {1: 1, 0: 5, 2: 0}, 16: {0: 1}, 18: {0: 0}, 0: {0: 0}}
# After DFS get a Combination:
# Candidate molecules respresenting in SMILES: ['O=Cc1ccnc2c1ccc1ccccc12', 'O=CCCCc1ccc2c(ccc3ccccc32)c1', 'O=Cc1cc2ccccc2c2ccccc12', 'O=CCCc1ccc2ccc3ccccc3c2c1', 'OCCc1nc2ccccc2c2ccccc12', 'c1ccc2c(c1)ccc1ccccc12', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc3ccccc23', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc1cccnc12', 'C1(C(C=CC=C2)=C2C3=C4CC=C3)=C4C=CC=C1', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C']
# Total atom counts: {'C': 180, 'H': 0, 'O': 5, 'N': 3, 'S': 0}
# 加丙烷前后
# ['O=Cc1ccnc2c1ccc1ccccc12', 'O=CCCCc1ccc2c(ccc3ccccc32)c1', 'O=Cc1cc2ccccc2c2ccccc12', 'O=CCCc1ccc2ccc3ccccc3c2c1', 'OCCc1nc2ccccc2c2ccccc12', 'c1ccc2c(c1)ccc1ccccc12', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc3ccccc23', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc1cccnc12', 'C1(C(C=CC=C2)=C2C3=C4CC=C3)=C4C=CC=C1'] ['C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C']
# ['O=C1CCCc2cnc3c(ccc4ccccc43)c21', 'O=C1CCCC(Cc2ccc3c(ccc4ccccc43)c2)C1', 'O=C1CCCc2c1c1ccccc1c1ccccc21', 'O=C1CCCC(c2ccc3ccc4ccccc4c3c2)C1', 'OCCc1nc2ccccc2c2ccccc12', 'c1ccc2c(c1)ccc1ccccc12', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc3ccccc23', 'c1ccc2cc3ccccc3cc2c1', 'c1ccc2c(c1)ccc1cccnc12', 'C1(C(C=CC=C2)=C2C3=C4CC=C3)=C4C=CC=C1'] ['C', 'C', 'C']
# Before connect: {'C': 29, 'H': 0, 'O': 1, 'N': 1, 'S': 0}, After connect: {'C': 31, 'H': 0, 'O': 1, 'N': 1, 'S': 0}
# Before connect: {'C': 34, 'H': 0, 'O': 1, 'N': 1, 'S': 0}, After connect: {'C': 36, 'H': 0, 'O': 1, 'N': 1, 'S': 0}
# Before connect: {'C': 34, 'H': 0, 'O': 1, 'N': 0, 'S': 0}, After connect: {'C': 36, 'H': 0, 'O': 1, 'N': 0, 'S': 0}
# Before connect: {'C': 27, 'H': 0, 'O': 0, 'N': 1, 'S': 0}, After connect: {'C': 29, 'H': 0, 'O': 0, 'N': 1, 'S': 0}
# Before connect: {'C': 39, 'H': 0, 'O': 2, 'N': 0, 'S': 0}, After connect: {'C': 41, 'H': 0, 'O': 2, 'N': 0, 'S': 0}
# Before connect: {'C': 14, 'H': 0, 'O': 0, 'N': 0, 'S': 0}, After connect: {'C': 14, 'H': 0, 'O': 0, 'N': 0, 'S': 0}
# Remaining 'C' in list2: 0
# methane_count:3
# SMILES component list: {'C': 187, 'H': 0, 'O': 5, 'N': 3, 'S': 0}
# 连接前的检查 {'C': 187, 'H': 0, 'O': 5, 'N': 3, 'S': 0}
# Predicted SMILES is O=C1c2c(c3ccccc3c3ccc4c(c23)Cc2c(CC3CCC(C5c6cnc7c(ccc8ccccc87)c6Cc6ccc7cc8ccccc8cc7c65)C(=O)C3C3CCc5cnc6c(ccc7cc8c(cc76)Cc6ccc7c(c6C8)c6c(c8ccccc87)C(C7CCC(c8cc9c(ccc%10ccccc%109)c9c8Cc8cc%10cc%11ccccc%11cc%10cc8C9)C(OCCc8nc9c%10c(ccc9c9ccccc89)Cc8c(ccc9ccc%11ccccc%11c89)C%10)C7=O)=CC6)c5C3=O)cc3ccc5ccccc5c3c2C4)CCC1c1cccc2ccc3ccccc3c12
# Predicted Chemical Fomula of final coal model is C187H0O5N3S0
# Unsatutated carbon rate of final coal model is 0.839572192513369
# Predicted elemental ratio of coal model is: {'C': 94.84648844968115, 'H': 0.0, 'O': 3.3785210524093077, 'N': 1.7749904979095403, 'S': 0.0}

# %%
# 根据smiles画分子图
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole 

smiles = current_smiles
mol = Chem.MolFromSmiles(smiles, sanitize=False)  # 创建分子时不进行sanitize操作

# 计算不饱和碳原子数量
unsaturated_C = 0
for atom in mol.GetAtoms():
    if atom.GetSymbol() == 'C':
        # 统计与碳原子连接的双键和三键
        for bond in atom.GetBonds():
            if bond.GetBondType() in (Chem.BondType.DOUBLE, Chem.BondType.TRIPLE):
                unsaturated_C += 1
                break  # 只计数一次，避免重复计算

print(f"不饱和碳原子数量: {unsaturated_C}")


img = Draw.MolToImage(mol, size=(600, 600))
img.show()
ut.calculate_unsaturated_carbon_ratio(smiles)
# Out:
# 不饱和碳原子数量: 6
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=600x600>
# 0.839572192513369
